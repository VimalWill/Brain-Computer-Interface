# %%
import pandas as pd
import matplotlib.pyplot as plt 
from scipy.io import loadmat

# %%
m = loadmat('/content/drive/MyDrive/Brain Computer Interface/data/subject_2/train_subject2_raw02.mat')

x = m['X']
y = m['Y']
print('shape of x:',x.shape)
print('shape of y:',y.shape)
# Out:
# shape of x: (121856, 32)
# shape of y: (121856, 1)

# %%
plt.plot(x[1])
plt.grid()
plt.show()

# %%
from sklearn.preprocessing import OneHotEncoder

onehot_encoder = OneHotEncoder(sparse=False)
onehot_encoded = onehot_encoder.fit_transform(y)
print(onehot_encoded.shape)
# Out:
# (121856, 3)

# %%
from sklearn.decomposition import FastICA
transformer = FastICA(n_components=24,random_state=0)
X_transformed = transformer.fit_transform(x)
X_transformed.shape
# Out:
# (121856, 24)

# %%
plt.plot(X_transformed[1])
plt.grid()
plt.show()

# %%
from scipy import signal
import numpy as np 

stft_feat = []
for i in range(len(x)):
  f, t, Zxx = signal.stft(X_transformed[i], fs= 512, nperseg=1000)
  stft_feat.append(np.abs(Zxx))
# Out:
# /usr/local/lib/python3.7/dist-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 1000 is greater than input length  = 24, using nperseg = 24
#   .format(nperseg, input_length))

# %%
stft_feat = np.asarray(stft_feat)
stft_feat.shape
# Out:
# (121856, 13, 3)

# %%
plt.matshow(stft_feat[1].T)
plt.show()

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(stft_feat, onehot_encoded, train_size=0.7, random_state=7)

# %%
import tensorflow as tf 
from tensorflow import keras
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, Activation, TimeDistributed,Flatten,LSTM 
from keras.models import Model

# %%
model = keras.models.load_model('/content/drive/MyDrive/Brain Computer Interface/model/model.h5')

# %%
import tensorflow as tf
dot_img_file = '/tmp/model_1.png'
tf.keras.utils.plot_model(model, to_file=dot_img_file, show_shapes=True)

# %%
model.compile(loss='categorical_crossentropy', optimizer=keras.optimizers.RMSprop(learning_rate=0.001), metrics=['accuracy'])
history = model.fit(X_train,y_train,validation_split=0.3,epochs=300,batch_size=64,verbose=1)
# Out:
# Epoch 1/300
# 933/933 [==============================] - 13s 11ms/step - loss: 1.0163 - accuracy: 0.4842 - val_loss: 0.9031 - val_accuracy: 0.5420
# Epoch 2/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.9174 - accuracy: 0.5350 - val_loss: 0.8305 - val_accuracy: 0.5882
# Epoch 3/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.8710 - accuracy: 0.5661 - val_loss: 0.8178 - val_accuracy: 0.6032
# Epoch 4/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.8392 - accuracy: 0.5962 - val_loss: 0.7982 - val_accuracy: 0.6081
# Epoch 5/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.8091 - accuracy: 0.6130 - val_loss: 0.7477 - val_accuracy: 0.6431
# Epoch 6/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.7897 - accuracy: 0.6275 - val_loss: 0.7453 - val_accuracy: 0.6485
# Epoch 7/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.7731 - accuracy: 0.6355 - val_loss: 0.6946 - val_accuracy: 0.6942
# Epoch 8/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.7554 - accuracy: 0.6494 - val_loss: 0.7186 - val_accuracy: 0.6604
# Epoch 9/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.7406 - accuracy: 0.6604 - val_loss: 0.6477 - val_accuracy: 0.7163
# Epoch 10/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.7282 - accuracy: 0.6669 - val_loss: 0.6355 - val_accuracy: 0.7352
# Epoch 11/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.7189 - accuracy: 0.6692 - val_loss: 0.6645 - val_accuracy: 0.6913
# Epoch 12/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.7038 - accuracy: 0.6794 - val_loss: 0.6281 - val_accuracy: 0.7141
# Epoch 13/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.6937 - accuracy: 0.6869 - val_loss: 0.5716 - val_accuracy: 0.7566
# Epoch 14/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.6839 - accuracy: 0.6934 - val_loss: 0.5670 - val_accuracy: 0.7655
# Epoch 15/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.6740 - accuracy: 0.6971 - val_loss: 0.6215 - val_accuracy: 0.7263
# Epoch 16/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.6649 - accuracy: 0.7028 - val_loss: 0.5529 - val_accuracy: 0.7641
# Epoch 17/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.6568 - accuracy: 0.7077 - val_loss: 0.5365 - val_accuracy: 0.7730
# Epoch 18/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.6478 - accuracy: 0.7149 - val_loss: 0.5468 - val_accuracy: 0.7683
# Epoch 19/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.6423 - accuracy: 0.7166 - val_loss: 0.5174 - val_accuracy: 0.7776
# Epoch 20/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.6332 - accuracy: 0.7217 - val_loss: 0.5443 - val_accuracy: 0.7654
# Epoch 21/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.6313 - accuracy: 0.7239 - val_loss: 0.5495 - val_accuracy: 0.7809
# Epoch 22/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.6236 - accuracy: 0.7271 - val_loss: 0.5388 - val_accuracy: 0.7720
# Epoch 23/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.6157 - accuracy: 0.7306 - val_loss: 0.6593 - val_accuracy: 0.7036
# Epoch 24/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.6056 - accuracy: 0.7384 - val_loss: 0.4801 - val_accuracy: 0.8062
# Epoch 25/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.6040 - accuracy: 0.7389 - val_loss: 0.4957 - val_accuracy: 0.7894
# Epoch 26/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.5975 - accuracy: 0.7428 - val_loss: 0.4814 - val_accuracy: 0.7978
# Epoch 27/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.5918 - accuracy: 0.7465 - val_loss: 0.5244 - val_accuracy: 0.7679
# Epoch 28/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.5867 - accuracy: 0.7502 - val_loss: 0.4874 - val_accuracy: 0.8021
# Epoch 29/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.5825 - accuracy: 0.7515 - val_loss: 0.4977 - val_accuracy: 0.7898
# Epoch 30/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.5775 - accuracy: 0.7544 - val_loss: 0.4164 - val_accuracy: 0.8376
# Epoch 31/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.5716 - accuracy: 0.7566 - val_loss: 0.4342 - val_accuracy: 0.8204
# Epoch 32/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.5667 - accuracy: 0.7590 - val_loss: 0.4693 - val_accuracy: 0.7991
# Epoch 33/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.5646 - accuracy: 0.7624 - val_loss: 0.4207 - val_accuracy: 0.8363
# Epoch 34/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.5552 - accuracy: 0.7669 - val_loss: 0.4597 - val_accuracy: 0.8132
# Epoch 35/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.5531 - accuracy: 0.7665 - val_loss: 0.4143 - val_accuracy: 0.8349
# Epoch 36/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.5512 - accuracy: 0.7682 - val_loss: 0.4157 - val_accuracy: 0.8351
# Epoch 37/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.5433 - accuracy: 0.7726 - val_loss: 0.3792 - val_accuracy: 0.8557
# Epoch 38/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.5405 - accuracy: 0.7735 - val_loss: 0.3902 - val_accuracy: 0.8559
# Epoch 39/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.5376 - accuracy: 0.7730 - val_loss: 0.5613 - val_accuracy: 0.7627
# Epoch 40/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.5308 - accuracy: 0.7794 - val_loss: 0.4236 - val_accuracy: 0.8343
# Epoch 41/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.5271 - accuracy: 0.7807 - val_loss: 0.3651 - val_accuracy: 0.8601
# Epoch 42/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.5270 - accuracy: 0.7809 - val_loss: 0.3593 - val_accuracy: 0.8675
# Epoch 43/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.5231 - accuracy: 0.7822 - val_loss: 0.3729 - val_accuracy: 0.8574
# Epoch 44/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.5197 - accuracy: 0.7846 - val_loss: 0.3953 - val_accuracy: 0.8457
# Epoch 45/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.5211 - accuracy: 0.7845 - val_loss: 0.3870 - val_accuracy: 0.8509
# Epoch 46/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.5168 - accuracy: 0.7855 - val_loss: 0.3702 - val_accuracy: 0.8640
# Epoch 47/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.5094 - accuracy: 0.7929 - val_loss: 0.3646 - val_accuracy: 0.8617
# Epoch 48/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.5079 - accuracy: 0.7930 - val_loss: 0.3463 - val_accuracy: 0.8745
# Epoch 49/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.5044 - accuracy: 0.7929 - val_loss: 0.3473 - val_accuracy: 0.8638
# Epoch 50/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.5040 - accuracy: 0.7930 - val_loss: 0.3685 - val_accuracy: 0.8511
# Epoch 51/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.4987 - accuracy: 0.7961 - val_loss: 0.3360 - val_accuracy: 0.8731
# Epoch 52/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.4969 - accuracy: 0.7955 - val_loss: 0.4490 - val_accuracy: 0.8168
# Epoch 53/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.4978 - accuracy: 0.7949 - val_loss: 0.3651 - val_accuracy: 0.8632
# Epoch 54/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.4945 - accuracy: 0.7985 - val_loss: 0.3233 - val_accuracy: 0.8837
# Epoch 55/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.4908 - accuracy: 0.7994 - val_loss: 0.3891 - val_accuracy: 0.8464
# Epoch 56/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.4888 - accuracy: 0.8024 - val_loss: 0.3260 - val_accuracy: 0.8794
# Epoch 57/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.4813 - accuracy: 0.8040 - val_loss: 0.3161 - val_accuracy: 0.8843
# Epoch 58/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.4790 - accuracy: 0.8052 - val_loss: 0.4038 - val_accuracy: 0.8391
# Epoch 59/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.4818 - accuracy: 0.8058 - val_loss: 0.3591 - val_accuracy: 0.8669
# Epoch 60/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.4766 - accuracy: 0.8073 - val_loss: 0.3407 - val_accuracy: 0.8716
# Epoch 61/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.4766 - accuracy: 0.8080 - val_loss: 0.3387 - val_accuracy: 0.8733
# Epoch 62/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.4800 - accuracy: 0.8073 - val_loss: 0.3173 - val_accuracy: 0.8885
# Epoch 63/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.4706 - accuracy: 0.8093 - val_loss: 0.3313 - val_accuracy: 0.8717
# Epoch 64/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.4680 - accuracy: 0.8106 - val_loss: 0.3052 - val_accuracy: 0.8900
# Epoch 65/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.4626 - accuracy: 0.8132 - val_loss: 0.3012 - val_accuracy: 0.8889
# Epoch 66/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.4652 - accuracy: 0.8134 - val_loss: 0.3809 - val_accuracy: 0.8512
# Epoch 67/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.4640 - accuracy: 0.8134 - val_loss: 0.2911 - val_accuracy: 0.8987
# Epoch 68/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.4620 - accuracy: 0.8142 - val_loss: 0.2952 - val_accuracy: 0.8918
# Epoch 69/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.4581 - accuracy: 0.8170 - val_loss: 0.3094 - val_accuracy: 0.8886
# Epoch 70/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.4606 - accuracy: 0.8151 - val_loss: 0.3353 - val_accuracy: 0.8759
# Epoch 71/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.4573 - accuracy: 0.8147 - val_loss: 0.3184 - val_accuracy: 0.8832
# Epoch 72/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.4555 - accuracy: 0.8164 - val_loss: 0.3593 - val_accuracy: 0.8644
# Epoch 73/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.4540 - accuracy: 0.8187 - val_loss: 0.2998 - val_accuracy: 0.8957
# Epoch 74/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.4460 - accuracy: 0.8225 - val_loss: 0.2808 - val_accuracy: 0.9020
# Epoch 75/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.4499 - accuracy: 0.8197 - val_loss: 0.2968 - val_accuracy: 0.8908
# Epoch 76/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.4474 - accuracy: 0.8238 - val_loss: 0.3344 - val_accuracy: 0.8686
# Epoch 77/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.4507 - accuracy: 0.8190 - val_loss: 0.3892 - val_accuracy: 0.8406
# Epoch 78/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.4448 - accuracy: 0.8219 - val_loss: 0.3011 - val_accuracy: 0.8893
# Epoch 79/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.4453 - accuracy: 0.8221 - val_loss: 0.2871 - val_accuracy: 0.9016
# Epoch 80/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.4439 - accuracy: 0.8209 - val_loss: 0.2826 - val_accuracy: 0.8957
# Epoch 81/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.4402 - accuracy: 0.8245 - val_loss: 0.3077 - val_accuracy: 0.8803
# Epoch 82/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.4406 - accuracy: 0.8258 - val_loss: 0.2934 - val_accuracy: 0.8884
# Epoch 83/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.4386 - accuracy: 0.8253 - val_loss: 0.3052 - val_accuracy: 0.8852
# Epoch 84/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.4380 - accuracy: 0.8233 - val_loss: 0.2694 - val_accuracy: 0.9043
# Epoch 85/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.4327 - accuracy: 0.8277 - val_loss: 0.3025 - val_accuracy: 0.8917
# Epoch 86/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.4318 - accuracy: 0.8298 - val_loss: 0.3062 - val_accuracy: 0.8911
# Epoch 87/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.4346 - accuracy: 0.8291 - val_loss: 0.3017 - val_accuracy: 0.8809
# Epoch 88/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.4286 - accuracy: 0.8311 - val_loss: 0.3261 - val_accuracy: 0.8711
# Epoch 89/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.4345 - accuracy: 0.8289 - val_loss: 0.2776 - val_accuracy: 0.8986
# Epoch 90/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.4243 - accuracy: 0.8327 - val_loss: 0.4117 - val_accuracy: 0.8188
# Epoch 91/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.4264 - accuracy: 0.8309 - val_loss: 0.2887 - val_accuracy: 0.9000
# Epoch 92/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.4301 - accuracy: 0.8320 - val_loss: 0.2526 - val_accuracy: 0.9186
# Epoch 93/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.4251 - accuracy: 0.8316 - val_loss: 0.2650 - val_accuracy: 0.9079
# Epoch 94/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.4243 - accuracy: 0.8342 - val_loss: 0.2736 - val_accuracy: 0.9048
# Epoch 95/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.4250 - accuracy: 0.8315 - val_loss: 0.3004 - val_accuracy: 0.8874
# Epoch 96/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.4253 - accuracy: 0.8335 - val_loss: 0.2818 - val_accuracy: 0.8937
# Epoch 97/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.4244 - accuracy: 0.8330 - val_loss: 0.2571 - val_accuracy: 0.9077
# Epoch 98/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.4169 - accuracy: 0.8363 - val_loss: 0.2623 - val_accuracy: 0.9038
# Epoch 99/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.4260 - accuracy: 0.8347 - val_loss: 0.4200 - val_accuracy: 0.8202
# Epoch 100/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.4234 - accuracy: 0.8323 - val_loss: 0.2458 - val_accuracy: 0.9121
# Epoch 101/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.4197 - accuracy: 0.8352 - val_loss: 0.3807 - val_accuracy: 0.8529
# Epoch 102/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.4196 - accuracy: 0.8350 - val_loss: 0.2728 - val_accuracy: 0.9031
# Epoch 103/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.4166 - accuracy: 0.8379 - val_loss: 0.2939 - val_accuracy: 0.8892
# Epoch 104/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.4110 - accuracy: 0.8387 - val_loss: 0.2880 - val_accuracy: 0.9039
# Epoch 105/300
# 933/933 [==============================] - 11s 12ms/step - loss: 0.4151 - accuracy: 0.8371 - val_loss: 0.3102 - val_accuracy: 0.8776
# Epoch 106/300
# 933/933 [==============================] - 11s 11ms/step - loss: 0.4099 - accuracy: 0.8373 - val_loss: 0.3777 - val_accuracy: 0.8502
# Epoch 107/300
# 933/933 [==============================] - 11s 11ms/step - loss: 0.4084 - accuracy: 0.8409 - val_loss: 0.2669 - val_accuracy: 0.9074
# Epoch 108/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.4124 - accuracy: 0.8375 - val_loss: 0.2728 - val_accuracy: 0.9031
# Epoch 109/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.4128 - accuracy: 0.8394 - val_loss: 0.3513 - val_accuracy: 0.8624
# Epoch 110/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.4107 - accuracy: 0.8396 - val_loss: 0.2631 - val_accuracy: 0.9042
# Epoch 111/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.4041 - accuracy: 0.8407 - val_loss: 0.2467 - val_accuracy: 0.9151
# Epoch 112/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.4102 - accuracy: 0.8375 - val_loss: 0.2627 - val_accuracy: 0.8964
# Epoch 113/300
# 933/933 [==============================] - 11s 11ms/step - loss: 0.4034 - accuracy: 0.8404 - val_loss: 0.3091 - val_accuracy: 0.8883
# Epoch 114/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.4080 - accuracy: 0.8404 - val_loss: 0.2733 - val_accuracy: 0.8970
# Epoch 115/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.4071 - accuracy: 0.8396 - val_loss: 0.2839 - val_accuracy: 0.9013
# Epoch 116/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.4051 - accuracy: 0.8422 - val_loss: 0.2960 - val_accuracy: 0.8860
# Epoch 117/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3989 - accuracy: 0.8441 - val_loss: 0.2463 - val_accuracy: 0.9143
# Epoch 118/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3984 - accuracy: 0.8449 - val_loss: 0.2626 - val_accuracy: 0.9069
# Epoch 119/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3994 - accuracy: 0.8442 - val_loss: 0.2431 - val_accuracy: 0.9114
# Epoch 120/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.4012 - accuracy: 0.8433 - val_loss: 0.2611 - val_accuracy: 0.9000
# Epoch 121/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.4025 - accuracy: 0.8434 - val_loss: 0.2428 - val_accuracy: 0.9127
# Epoch 122/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.4002 - accuracy: 0.8443 - val_loss: 0.2524 - val_accuracy: 0.9029
# Epoch 123/300
# 933/933 [==============================] - 10s 10ms/step - loss: 0.3976 - accuracy: 0.8445 - val_loss: 0.2308 - val_accuracy: 0.9171
# Epoch 124/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3925 - accuracy: 0.8476 - val_loss: 0.2661 - val_accuracy: 0.8980
# Epoch 125/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.4025 - accuracy: 0.8466 - val_loss: 0.2778 - val_accuracy: 0.8983
# Epoch 126/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3993 - accuracy: 0.8450 - val_loss: 0.2705 - val_accuracy: 0.9058
# Epoch 127/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3923 - accuracy: 0.8469 - val_loss: 0.2433 - val_accuracy: 0.9121
# Epoch 128/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3915 - accuracy: 0.8458 - val_loss: 0.2573 - val_accuracy: 0.9130
# Epoch 129/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3910 - accuracy: 0.8472 - val_loss: 0.2982 - val_accuracy: 0.8898
# Epoch 130/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3909 - accuracy: 0.8483 - val_loss: 0.2264 - val_accuracy: 0.9201
# Epoch 131/300
# 933/933 [==============================] - 11s 12ms/step - loss: 0.3931 - accuracy: 0.8468 - val_loss: 0.2979 - val_accuracy: 0.8918
# Epoch 132/300
# 933/933 [==============================] - 11s 11ms/step - loss: 0.3960 - accuracy: 0.8468 - val_loss: 0.3510 - val_accuracy: 0.8628
# Epoch 133/300
# 933/933 [==============================] - 11s 12ms/step - loss: 0.3900 - accuracy: 0.8487 - val_loss: 0.3182 - val_accuracy: 0.8767
# Epoch 134/300
# 933/933 [==============================] - 11s 12ms/step - loss: 0.3938 - accuracy: 0.8477 - val_loss: 0.2643 - val_accuracy: 0.9066
# Epoch 135/300
# 933/933 [==============================] - 11s 12ms/step - loss: 0.3945 - accuracy: 0.8459 - val_loss: 0.2306 - val_accuracy: 0.9191
# Epoch 136/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3928 - accuracy: 0.8482 - val_loss: 0.2595 - val_accuracy: 0.9078
# Epoch 137/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3909 - accuracy: 0.8490 - val_loss: 0.2316 - val_accuracy: 0.9259
# Epoch 138/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3838 - accuracy: 0.8515 - val_loss: 0.2750 - val_accuracy: 0.8959
# Epoch 139/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3862 - accuracy: 0.8521 - val_loss: 0.2144 - val_accuracy: 0.9293
# Epoch 140/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3819 - accuracy: 0.8519 - val_loss: 0.2386 - val_accuracy: 0.9164
# Epoch 141/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3807 - accuracy: 0.8520 - val_loss: 0.2626 - val_accuracy: 0.8999
# Epoch 142/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3861 - accuracy: 0.8519 - val_loss: 0.3249 - val_accuracy: 0.8709
# Epoch 143/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3880 - accuracy: 0.8524 - val_loss: 0.2293 - val_accuracy: 0.9204
# Epoch 144/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3920 - accuracy: 0.8508 - val_loss: 0.2444 - val_accuracy: 0.9131
# Epoch 145/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3817 - accuracy: 0.8527 - val_loss: 0.2247 - val_accuracy: 0.9243
# Epoch 146/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3807 - accuracy: 0.8526 - val_loss: 0.2102 - val_accuracy: 0.9274
# Epoch 147/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3788 - accuracy: 0.8528 - val_loss: 0.2771 - val_accuracy: 0.9027
# Epoch 148/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3792 - accuracy: 0.8547 - val_loss: 0.2761 - val_accuracy: 0.8943
# Epoch 149/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3766 - accuracy: 0.8541 - val_loss: 0.2358 - val_accuracy: 0.9134
# Epoch 150/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3819 - accuracy: 0.8533 - val_loss: 0.2250 - val_accuracy: 0.9302
# Epoch 151/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3770 - accuracy: 0.8537 - val_loss: 0.2906 - val_accuracy: 0.8877
# Epoch 152/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3878 - accuracy: 0.8530 - val_loss: 0.2119 - val_accuracy: 0.9296
# Epoch 153/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3762 - accuracy: 0.8543 - val_loss: 0.2462 - val_accuracy: 0.9107
# Epoch 154/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3746 - accuracy: 0.8564 - val_loss: 0.2243 - val_accuracy: 0.9222
# Epoch 155/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3799 - accuracy: 0.8542 - val_loss: 0.2411 - val_accuracy: 0.9152
# Epoch 156/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3716 - accuracy: 0.8572 - val_loss: 0.2044 - val_accuracy: 0.9283
# Epoch 157/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3756 - accuracy: 0.8555 - val_loss: 0.2341 - val_accuracy: 0.9183
# Epoch 158/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3781 - accuracy: 0.8542 - val_loss: 0.3319 - val_accuracy: 0.8760
# Epoch 159/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3715 - accuracy: 0.8565 - val_loss: 0.2327 - val_accuracy: 0.9183
# Epoch 160/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3736 - accuracy: 0.8561 - val_loss: 0.2436 - val_accuracy: 0.9081
# Epoch 161/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3710 - accuracy: 0.8555 - val_loss: 0.2377 - val_accuracy: 0.9154
# Epoch 162/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3724 - accuracy: 0.8573 - val_loss: 0.2308 - val_accuracy: 0.9222
# Epoch 163/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3679 - accuracy: 0.8565 - val_loss: 0.3549 - val_accuracy: 0.8554
# Epoch 164/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3729 - accuracy: 0.8551 - val_loss: 0.2454 - val_accuracy: 0.9044
# Epoch 165/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3871 - accuracy: 0.8594 - val_loss: 0.2082 - val_accuracy: 0.9360
# Epoch 166/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3706 - accuracy: 0.8574 - val_loss: 0.2949 - val_accuracy: 0.8886
# Epoch 167/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3674 - accuracy: 0.8584 - val_loss: 0.2107 - val_accuracy: 0.9286
# Epoch 168/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3696 - accuracy: 0.8578 - val_loss: 0.2371 - val_accuracy: 0.9159
# Epoch 169/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3652 - accuracy: 0.8594 - val_loss: 0.2069 - val_accuracy: 0.9335
# Epoch 170/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3670 - accuracy: 0.8589 - val_loss: 0.2035 - val_accuracy: 0.9323
# Epoch 171/300
# 933/933 [==============================] - 11s 11ms/step - loss: 0.3649 - accuracy: 0.8594 - val_loss: 0.2646 - val_accuracy: 0.9142
# Epoch 172/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3686 - accuracy: 0.8576 - val_loss: 0.2422 - val_accuracy: 0.9064
# Epoch 173/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3653 - accuracy: 0.8605 - val_loss: 0.2473 - val_accuracy: 0.9128
# Epoch 174/300
# 933/933 [==============================] - 11s 11ms/step - loss: 0.3696 - accuracy: 0.8591 - val_loss: 0.2045 - val_accuracy: 0.9372
# Epoch 175/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3636 - accuracy: 0.8601 - val_loss: 0.2135 - val_accuracy: 0.9215
# Epoch 176/300
# 933/933 [==============================] - 11s 11ms/step - loss: 0.3624 - accuracy: 0.8612 - val_loss: 0.2193 - val_accuracy: 0.9237
# Epoch 177/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3674 - accuracy: 0.8612 - val_loss: 0.2333 - val_accuracy: 0.9224
# Epoch 178/300
# 933/933 [==============================] - 11s 11ms/step - loss: 0.3660 - accuracy: 0.8605 - val_loss: 0.2849 - val_accuracy: 0.8911
# Epoch 179/300
# 933/933 [==============================] - 11s 12ms/step - loss: 0.3669 - accuracy: 0.8594 - val_loss: 0.2329 - val_accuracy: 0.9184
# Epoch 180/300
# 933/933 [==============================] - 11s 12ms/step - loss: 0.3673 - accuracy: 0.8596 - val_loss: 0.2569 - val_accuracy: 0.9068
# Epoch 181/300
# 933/933 [==============================] - 11s 12ms/step - loss: 0.3627 - accuracy: 0.8638 - val_loss: 0.2331 - val_accuracy: 0.9192
# Epoch 182/300
# 933/933 [==============================] - 11s 12ms/step - loss: 0.3635 - accuracy: 0.8604 - val_loss: 0.2488 - val_accuracy: 0.9192
# Epoch 183/300
# 933/933 [==============================] - 11s 12ms/step - loss: 0.3574 - accuracy: 0.8636 - val_loss: 0.2382 - val_accuracy: 0.9109
# Epoch 184/300
# 933/933 [==============================] - 11s 12ms/step - loss: 0.3604 - accuracy: 0.8604 - val_loss: 0.2691 - val_accuracy: 0.8958
# Epoch 185/300
# 933/933 [==============================] - 11s 12ms/step - loss: 0.3600 - accuracy: 0.8614 - val_loss: 0.2256 - val_accuracy: 0.9257
# Epoch 186/300
# 933/933 [==============================] - 11s 12ms/step - loss: 0.3642 - accuracy: 0.8622 - val_loss: 0.2269 - val_accuracy: 0.9171
# Epoch 187/300
# 933/933 [==============================] - 11s 12ms/step - loss: 0.3608 - accuracy: 0.8605 - val_loss: 0.3156 - val_accuracy: 0.8857
# Epoch 188/300
# 933/933 [==============================] - 11s 12ms/step - loss: 0.3700 - accuracy: 0.8622 - val_loss: 0.2235 - val_accuracy: 0.9243
# Epoch 189/300
# 933/933 [==============================] - 11s 12ms/step - loss: 0.3636 - accuracy: 0.8611 - val_loss: 0.2365 - val_accuracy: 0.9148
# Epoch 190/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3595 - accuracy: 0.8628 - val_loss: 0.2956 - val_accuracy: 0.8891
# Epoch 191/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3563 - accuracy: 0.8640 - val_loss: 0.2397 - val_accuracy: 0.9189
# Epoch 192/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3692 - accuracy: 0.8637 - val_loss: 0.2315 - val_accuracy: 0.9284
# Epoch 193/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3557 - accuracy: 0.8633 - val_loss: 0.2114 - val_accuracy: 0.9288
# Epoch 194/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3585 - accuracy: 0.8619 - val_loss: 0.2380 - val_accuracy: 0.9126
# Epoch 195/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3579 - accuracy: 0.8627 - val_loss: 0.1813 - val_accuracy: 0.9417
# Epoch 196/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3625 - accuracy: 0.8616 - val_loss: 0.2546 - val_accuracy: 0.9076
# Epoch 197/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3607 - accuracy: 0.8633 - val_loss: 0.2037 - val_accuracy: 0.9367
# Epoch 198/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3513 - accuracy: 0.8657 - val_loss: 0.1980 - val_accuracy: 0.9290
# Epoch 199/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3635 - accuracy: 0.8647 - val_loss: 0.1922 - val_accuracy: 0.9347
# Epoch 200/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3561 - accuracy: 0.8631 - val_loss: 0.2292 - val_accuracy: 0.9242
# Epoch 201/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3515 - accuracy: 0.8662 - val_loss: 0.1905 - val_accuracy: 0.9408
# Epoch 202/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3571 - accuracy: 0.8658 - val_loss: 0.2095 - val_accuracy: 0.9344
# Epoch 203/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3551 - accuracy: 0.8638 - val_loss: 0.2013 - val_accuracy: 0.9326
# Epoch 204/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3526 - accuracy: 0.8668 - val_loss: 0.2091 - val_accuracy: 0.9336
# Epoch 205/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3568 - accuracy: 0.8671 - val_loss: 0.2582 - val_accuracy: 0.9189
# Epoch 206/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3539 - accuracy: 0.8653 - val_loss: 0.1983 - val_accuracy: 0.9358
# Epoch 207/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3551 - accuracy: 0.8653 - val_loss: 0.2484 - val_accuracy: 0.9070
# Epoch 208/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3560 - accuracy: 0.8665 - val_loss: 0.2157 - val_accuracy: 0.9287
# Epoch 209/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3512 - accuracy: 0.8637 - val_loss: 0.2050 - val_accuracy: 0.9275
# Epoch 210/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3552 - accuracy: 0.8631 - val_loss: 0.1900 - val_accuracy: 0.9393
# Epoch 211/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3497 - accuracy: 0.8652 - val_loss: 0.2448 - val_accuracy: 0.9135
# Epoch 212/300
# 933/933 [==============================] - 11s 11ms/step - loss: 0.3501 - accuracy: 0.8661 - val_loss: 0.2032 - val_accuracy: 0.9298
# Epoch 213/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3590 - accuracy: 0.8643 - val_loss: 0.1967 - val_accuracy: 0.9363
# Epoch 214/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3535 - accuracy: 0.8654 - val_loss: 0.1870 - val_accuracy: 0.9377
# Epoch 215/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3446 - accuracy: 0.8698 - val_loss: 0.1894 - val_accuracy: 0.9340
# Epoch 216/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3582 - accuracy: 0.8661 - val_loss: 0.1951 - val_accuracy: 0.9308
# Epoch 217/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3468 - accuracy: 0.8691 - val_loss: 0.1890 - val_accuracy: 0.9368
# Epoch 218/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3530 - accuracy: 0.8668 - val_loss: 0.1953 - val_accuracy: 0.9380
# Epoch 219/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3578 - accuracy: 0.8653 - val_loss: 0.1790 - val_accuracy: 0.9403
# Epoch 220/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3475 - accuracy: 0.8682 - val_loss: 0.2741 - val_accuracy: 0.8982
# Epoch 221/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3534 - accuracy: 0.8671 - val_loss: 0.2142 - val_accuracy: 0.9343
# Epoch 222/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3488 - accuracy: 0.8679 - val_loss: 0.2367 - val_accuracy: 0.9175
# Epoch 223/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3460 - accuracy: 0.8679 - val_loss: 0.1909 - val_accuracy: 0.9358
# Epoch 224/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3538 - accuracy: 0.8664 - val_loss: 0.1958 - val_accuracy: 0.9353
# Epoch 225/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3512 - accuracy: 0.8669 - val_loss: 0.1977 - val_accuracy: 0.9353
# Epoch 226/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3536 - accuracy: 0.8677 - val_loss: 0.1969 - val_accuracy: 0.9319
# Epoch 227/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3450 - accuracy: 0.8704 - val_loss: 0.2159 - val_accuracy: 0.9305
# Epoch 228/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3460 - accuracy: 0.8704 - val_loss: 0.1790 - val_accuracy: 0.9445
# Epoch 229/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3447 - accuracy: 0.8692 - val_loss: 0.2305 - val_accuracy: 0.9240
# Epoch 230/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3473 - accuracy: 0.8686 - val_loss: 0.2251 - val_accuracy: 0.9252
# Epoch 231/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3481 - accuracy: 0.8693 - val_loss: 0.1952 - val_accuracy: 0.9305
# Epoch 232/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3466 - accuracy: 0.8702 - val_loss: 0.2224 - val_accuracy: 0.9207
# Epoch 233/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3482 - accuracy: 0.8688 - val_loss: 0.2234 - val_accuracy: 0.9206
# Epoch 234/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3438 - accuracy: 0.8701 - val_loss: 0.2464 - val_accuracy: 0.9096
# Epoch 235/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3434 - accuracy: 0.8689 - val_loss: 0.1913 - val_accuracy: 0.9448
# Epoch 236/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3446 - accuracy: 0.8706 - val_loss: 0.2066 - val_accuracy: 0.9349
# Epoch 237/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3475 - accuracy: 0.8692 - val_loss: 0.1954 - val_accuracy: 0.9323
# Epoch 238/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3425 - accuracy: 0.8723 - val_loss: 0.2077 - val_accuracy: 0.9249
# Epoch 239/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3378 - accuracy: 0.8734 - val_loss: 0.1832 - val_accuracy: 0.9403
# Epoch 240/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3403 - accuracy: 0.8710 - val_loss: 0.1803 - val_accuracy: 0.9436
# Epoch 241/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3398 - accuracy: 0.8722 - val_loss: 0.1913 - val_accuracy: 0.9356
# Epoch 242/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3411 - accuracy: 0.8726 - val_loss: 0.2227 - val_accuracy: 0.9259
# Epoch 243/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3516 - accuracy: 0.8711 - val_loss: 0.1835 - val_accuracy: 0.9435
# Epoch 244/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3366 - accuracy: 0.8731 - val_loss: 0.3032 - val_accuracy: 0.8948
# Epoch 245/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3429 - accuracy: 0.8709 - val_loss: 0.1980 - val_accuracy: 0.9335
# Epoch 246/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3369 - accuracy: 0.8721 - val_loss: 0.1841 - val_accuracy: 0.9388
# Epoch 247/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3418 - accuracy: 0.8716 - val_loss: 0.2306 - val_accuracy: 0.9130
# Epoch 248/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3411 - accuracy: 0.8724 - val_loss: 0.2043 - val_accuracy: 0.9279
# Epoch 249/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3397 - accuracy: 0.8730 - val_loss: 0.1819 - val_accuracy: 0.9423
# Epoch 250/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3381 - accuracy: 0.8731 - val_loss: 0.1844 - val_accuracy: 0.9400
# Epoch 251/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3351 - accuracy: 0.8742 - val_loss: 0.2139 - val_accuracy: 0.9256
# Epoch 252/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3390 - accuracy: 0.8729 - val_loss: 0.2131 - val_accuracy: 0.9299
# Epoch 253/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3385 - accuracy: 0.8735 - val_loss: 0.1811 - val_accuracy: 0.9450
# Epoch 254/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3391 - accuracy: 0.8727 - val_loss: 0.2165 - val_accuracy: 0.9206
# Epoch 255/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3329 - accuracy: 0.8746 - val_loss: 0.2026 - val_accuracy: 0.9320
# Epoch 256/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3447 - accuracy: 0.8711 - val_loss: 0.1863 - val_accuracy: 0.9370
# Epoch 257/300
# 933/933 [==============================] - 11s 11ms/step - loss: 0.3708 - accuracy: 0.8731 - val_loss: 0.1783 - val_accuracy: 0.9416
# Epoch 258/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3347 - accuracy: 0.8741 - val_loss: 0.1918 - val_accuracy: 0.9330
# Epoch 259/300
# 933/933 [==============================] - 11s 11ms/step - loss: 0.3400 - accuracy: 0.8725 - val_loss: 0.2117 - val_accuracy: 0.9299
# Epoch 260/300
# 933/933 [==============================] - 11s 11ms/step - loss: 0.3344 - accuracy: 0.8748 - val_loss: 0.1965 - val_accuracy: 0.9313
# Epoch 261/300
# 933/933 [==============================] - 11s 11ms/step - loss: 0.3421 - accuracy: 0.8737 - val_loss: 0.1851 - val_accuracy: 0.9420
# Epoch 262/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3335 - accuracy: 0.8742 - val_loss: 0.1836 - val_accuracy: 0.9374
# Epoch 263/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3357 - accuracy: 0.8753 - val_loss: 0.1857 - val_accuracy: 0.9377
# Epoch 264/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3360 - accuracy: 0.8735 - val_loss: 0.2374 - val_accuracy: 0.9170
# Epoch 265/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3353 - accuracy: 0.8737 - val_loss: 0.2064 - val_accuracy: 0.9282
# Epoch 266/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3383 - accuracy: 0.8743 - val_loss: 0.2130 - val_accuracy: 0.9214
# Epoch 267/300
# 933/933 [==============================] - 11s 11ms/step - loss: 0.3282 - accuracy: 0.8769 - val_loss: 0.1876 - val_accuracy: 0.9331
# Epoch 268/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3372 - accuracy: 0.8764 - val_loss: 0.1914 - val_accuracy: 0.9324
# Epoch 269/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3290 - accuracy: 0.8773 - val_loss: 0.1728 - val_accuracy: 0.9465
# Epoch 270/300
# 933/933 [==============================] - 11s 11ms/step - loss: 0.3408 - accuracy: 0.8759 - val_loss: 0.2930 - val_accuracy: 0.8808
# Epoch 271/300
# 933/933 [==============================] - 11s 12ms/step - loss: 0.3364 - accuracy: 0.8729 - val_loss: 0.1974 - val_accuracy: 0.9424
# Epoch 272/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3293 - accuracy: 0.8764 - val_loss: 0.1815 - val_accuracy: 0.9434
# Epoch 273/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3297 - accuracy: 0.8772 - val_loss: 0.2116 - val_accuracy: 0.9268
# Epoch 274/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3306 - accuracy: 0.8774 - val_loss: 0.1877 - val_accuracy: 0.9336
# Epoch 275/300
# 933/933 [==============================] - 11s 11ms/step - loss: 0.3281 - accuracy: 0.8770 - val_loss: 0.2267 - val_accuracy: 0.9147
# Epoch 276/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3261 - accuracy: 0.8787 - val_loss: 0.1710 - val_accuracy: 0.9464
# Epoch 277/300
# 933/933 [==============================] - 11s 11ms/step - loss: 0.3309 - accuracy: 0.8756 - val_loss: 0.2107 - val_accuracy: 0.9230
# Epoch 278/300
# 933/933 [==============================] - 11s 12ms/step - loss: 0.3298 - accuracy: 0.8779 - val_loss: 0.1678 - val_accuracy: 0.9488
# Epoch 279/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3255 - accuracy: 0.8774 - val_loss: 0.1943 - val_accuracy: 0.9374
# Epoch 280/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3303 - accuracy: 0.8769 - val_loss: 0.2019 - val_accuracy: 0.9259
# Epoch 281/300
# 933/933 [==============================] - 11s 11ms/step - loss: 0.3235 - accuracy: 0.8805 - val_loss: 0.1922 - val_accuracy: 0.9379
# Epoch 282/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3269 - accuracy: 0.8761 - val_loss: 0.1781 - val_accuracy: 0.9414
# Epoch 283/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3230 - accuracy: 0.8777 - val_loss: 0.1786 - val_accuracy: 0.9461
# Epoch 284/300
# 933/933 [==============================] - 11s 11ms/step - loss: 0.3312 - accuracy: 0.8772 - val_loss: 0.1805 - val_accuracy: 0.9397
# Epoch 285/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3297 - accuracy: 0.8762 - val_loss: 0.2032 - val_accuracy: 0.9389
# Epoch 286/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3316 - accuracy: 0.8758 - val_loss: 0.2106 - val_accuracy: 0.9301
# Epoch 287/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3258 - accuracy: 0.8775 - val_loss: 0.1786 - val_accuracy: 0.9429
# Epoch 288/300
# 933/933 [==============================] - 11s 11ms/step - loss: 0.3256 - accuracy: 0.8778 - val_loss: 0.2415 - val_accuracy: 0.9097
# Epoch 289/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3248 - accuracy: 0.8782 - val_loss: 0.2443 - val_accuracy: 0.9177
# Epoch 290/300
# 933/933 [==============================] - 11s 11ms/step - loss: 0.3264 - accuracy: 0.8778 - val_loss: 0.1972 - val_accuracy: 0.9299
# Epoch 291/300
# 933/933 [==============================] - 11s 11ms/step - loss: 0.3258 - accuracy: 0.8779 - val_loss: 0.1767 - val_accuracy: 0.9406
# Epoch 292/300
# 933/933 [==============================] - 11s 11ms/step - loss: 0.3353 - accuracy: 0.8782 - val_loss: 0.1736 - val_accuracy: 0.9465
# Epoch 293/300
# 933/933 [==============================] - 11s 11ms/step - loss: 0.3229 - accuracy: 0.8780 - val_loss: 0.2777 - val_accuracy: 0.9002
# Epoch 294/300
# 933/933 [==============================] - 11s 11ms/step - loss: 0.3242 - accuracy: 0.8794 - val_loss: 0.1965 - val_accuracy: 0.9345
# Epoch 295/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3331 - accuracy: 0.8800 - val_loss: 0.2495 - val_accuracy: 0.9078
# Epoch 296/300
# 933/933 [==============================] - 11s 11ms/step - loss: 0.3148 - accuracy: 0.8816 - val_loss: 0.1790 - val_accuracy: 0.9414
# Epoch 297/300
# 933/933 [==============================] - 10s 11ms/step - loss: 0.3208 - accuracy: 0.8794 - val_loss: 0.1682 - val_accuracy: 0.9479
# Epoch 298/300
# 933/933 [==============================] - 11s 11ms/step - loss: 0.3190 - accuracy: 0.8786 - val_loss: 0.1690 - val_accuracy: 0.9434
# Epoch 299/300
# 933/933 [==============================] - 11s 11ms/step - loss: 0.3173 - accuracy: 0.8810 - val_loss: 0.1962 - val_accuracy: 0.9396
# Epoch 300/300
# 933/933 [==============================] - 11s 11ms/step - loss: 0.3152 - accuracy: 0.8814 - val_loss: 0.1786 - val_accuracy: 0.9445

# %%
# evaluate model
import time
start_time = time.time()
y_pred = model.predict(X_test, batch_size=64)
elapsed_time = time.time() - start_time
print(f"Elapsed time for prediction: {elapsed_time:.3f} seconds")
score = model.evaluate(X_test, y_test)
score
# Out:
# Elapsed time for prediction: 1.910 seconds
# 1143/1143 [==============================] - 3s 2ms/step - loss: 0.1865 - accuracy: 0.9405
# [0.18648211658000946, 0.9405312538146973]

# %%
epochs = [i for i in range(300)]
loss_train = history.history['loss']
acc_train = history.history['accuracy']
loss_test = history.history['val_loss']
acc_test = history.history['val_accuracy']


fig, ax = plt.subplots(1,2, figsize=(14,5))

ax[0].plot(epochs, loss_train, color='blue', label='Train Loss')
ax[0].plot(epochs, loss_test, color='orange', label='Validation Loss')
ax[0].set_title('Train and Validation Loss', fontsize=14)
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Loss')
ax[0].legend()



ax[1].plot(epochs, acc_train, color='blue', label='Train Accuracy')
ax[1].plot(epochs, acc_test, color='orange',  label='Validation Accuracy')
ax[1].set_title('Train and Validation Accuracy', fontsize=13)
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Accuracy')
ax[1].legend()
plt.show()

# %%
import time 
s1 = time.time()
y_pred = model.predict(X_test)
s2 = time.time()
s = s2 -s1 
print(s)
# Out:
# 2.2534115314483643

# %%
import numpy as np
y_test_non_category = [ np.argmax(t) for t in y_test ]
y_predict_non_category = [ np.argmax(t) for t in y_pred ]

# %%
from sklearn.metrics import confusion_matrix
confusion = confusion_matrix(y_test_non_category, y_predict_non_category)
print('Confusion Matrix\n')
print(confusion)

#importing accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
print('\nAccuracy: {:.2f}\n'.format(accuracy_score(y_test_non_category, y_predict_non_category)))

print('Micro Precision: {:.2f}'.format(precision_score(y_test_non_category, y_predict_non_category, average='micro')))
print('Micro Recall: {:.2f}'.format(recall_score(y_test_non_category, y_predict_non_category, average='micro')))
print('Micro F1-score: {:.2f}\n'.format(f1_score(y_test_non_category, y_predict_non_category, average='micro')))

print('Macro Precision: {:.2f}'.format(precision_score(y_test_non_category, y_predict_non_category, average='macro')))

print('Macro Recall: {:.2f}'.format(recall_score(y_test_non_category, y_predict_non_category, average='macro')))
print('Macro F1-score: {:.2f}\n'.format(f1_score(y_test_non_category, y_predict_non_category, average='macro')))

print('Weighted Precision: {:.2f}'.format(precision_score(y_test_non_category, y_predict_non_category, average='weighted')))
print('Weighted Recall: {:.2f}'.format(recall_score(y_test_non_category,y_predict_non_category, average='weighted')))
print('Weighted F1-score: {:.2f}'.format(f1_score(y_test_non_category, y_predict_non_category, average='weighted')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_test_non_category, y_predict_non_category, target_names=['Class 1', 'Class 2', 'Class 3']))
# Out:
# Confusion Matrix
#
# [[11513   365   521]
#  [  282 11634   508]
#  [  319   179 11236]]
#
# Accuracy: 0.94
#
# Micro Precision: 0.94
# Micro Recall: 0.94
# Micro F1-score: 0.94
#
# Macro Precision: 0.94
# Macro Recall: 0.94
# Macro F1-score: 0.94
#
# Weighted Precision: 0.94
# Weighted Recall: 0.94
# Weighted F1-score: 0.94
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#      Class 1       0.95      0.93      0.94     12399
#      Class 2       0.96      0.94      0.95     12424
#      Class 3       0.92      0.96      0.94     11734
#
#     accuracy                           0.94     36557
#    macro avg       0.94      0.94      0.94     36557
# weighted avg       0.94      0.94      0.94     36557

# %%
import seaborn as sns
from sklearn import metrics
cnf_matrix = metrics.confusion_matrix(y_test_non_category, y_predict_non_category)
cnf_matrix
# %matplotlib inline
class_names=[0,1]
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 257.44, 'Predicted label')

# %%
from itertools import cycle
from sklearn.metrics import roc_curve, auc

# %%
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(3):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_pred.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# %%
# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(3)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(3):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= 3

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
plt.figure()
plt.plot(
    fpr["micro"],
    tpr["micro"],
    label="micro-average ROC curve (area = {0:0.2f})".format(roc_auc["micro"]),
    color="deeppink",
    linestyle=":",
    linewidth=4,
)

plt.plot(
    fpr["macro"],
    tpr["macro"],
    label="macro-average ROC curve (area = {0:0.2f})".format(roc_auc["macro"]),
    color="navy",
    linestyle=":",
    linewidth=4,
)

colors = cycle(["aqua", "darkorange", "cornflowerblue"])
for i, color in zip(range(3), colors):
    plt.plot(
        fpr[i],
        tpr[i],
        color=color,
        lw=2,
        label="ROC curve of class {0} (area = {1:0.2f})".format(i, roc_auc[i]),
    )

plt.plot([0, 1], [0, 1], "k--", lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Some extension of Receiver operating characteristic to multiclass")
plt.legend(loc="lower right")
plt.show()
