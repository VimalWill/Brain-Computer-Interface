# %%
import pandas as pd
import matplotlib.pyplot as plt 
from scipy.io import loadmat

# %%
m = loadmat('/content/drive/MyDrive/Brain Computer Interface/data/subject_3/train_subject3_raw01.mat')

x = m['X']
y = m['Y']
print('shape of x:',x.shape)
print('shape of y:',y.shape)
# Out:
# shape of x: (121344, 32)
# shape of y: (121344, 1)

# %%
plt.plot(x[1])
plt.grid()
plt.show()

# %%
from sklearn.preprocessing import OneHotEncoder

onehot_encoder = OneHotEncoder(sparse=False)
onehot_encoded = onehot_encoder.fit_transform(y)
print(onehot_encoded.shape)
# Out:
# (121344, 3)

# %%
from sklearn.decomposition import FastICA
transformer = FastICA(n_components=24,random_state=0)
X_transformed = transformer.fit_transform(x)
X_transformed.shape
# Out:
# (121344, 24)

# %%
plt.plot(X_transformed[1])
plt.grid()
plt.show()

# %%
from skimage.restoration import denoise_wavelet

x_denoise = denoise_wavelet(X_transformed, method='BayesShrink', mode='soft', wavelet_levels=3, wavelet='sym8', rescale_sigma='True')
# Out:
# /usr/local/lib/python3.7/dist-packages/pywt/_multilevel.py:45: UserWarning: Level value of 3 is too high: all coefficients will experience boundary effects.
#   "boundary effects.").format(level))

# %%
plt.plot(x_denoise[1])
plt.grid()
plt.show()

# %%
from scipy import signal
import numpy as np 

stft_feat = []
for i in range(len(x)):
  f, t, Zxx = signal.stft(x_denoise[i], fs= 512, nperseg=1000)
  stft_feat.append(np.abs(Zxx))
# Out:
# /usr/local/lib/python3.7/dist-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 1000 is greater than input length  = 24, using nperseg = 24
#   .format(nperseg, input_length))

# %%
stft_feat = np.asarray(stft_feat)
stft_feat.shape
# Out:
# (121344, 13, 3)

# %%
plt.matshow(stft_feat[1].T)
plt.show()

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(stft_feat, onehot_encoded, train_size=0.7, random_state=7)

# %%
import tensorflow as tf 
from tensorflow import keras
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, Activation, TimeDistributed,Flatten,LSTM 
from keras.models import Model

# %%
model = keras.models.load_model('/content/drive/MyDrive/Brain Computer Interface/model/model.h5')

# %%
import tensorflow as tf
dot_img_file = '/tmp/model_1.png'
tf.keras.utils.plot_model(model, to_file=dot_img_file, show_shapes=True)

# %%
model.compile(loss='categorical_crossentropy', optimizer=keras.optimizers.RMSprop(learning_rate=0.001), metrics=['accuracy'])
history = model.fit(X_train,y_train,validation_split=0.3,epochs=300,batch_size=64,verbose=1)
# Out:
# Epoch 1/300
# 930/930 [==============================] - 17s 15ms/step - loss: 0.9943 - accuracy: 0.5291 - val_loss: 1.0010 - val_accuracy: 0.4336
# Epoch 2/300
# 930/930 [==============================] - 15s 16ms/step - loss: 0.9017 - accuracy: 0.5694 - val_loss: 0.8484 - val_accuracy: 0.6026
# Epoch 3/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.8644 - accuracy: 0.5917 - val_loss: 0.8374 - val_accuracy: 0.5627
# Epoch 4/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.8407 - accuracy: 0.6083 - val_loss: 0.8614 - val_accuracy: 0.5927
# Epoch 5/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.8205 - accuracy: 0.6206 - val_loss: 0.8947 - val_accuracy: 0.5605
# Epoch 6/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.8003 - accuracy: 0.6314 - val_loss: 0.8433 - val_accuracy: 0.5874
# Epoch 7/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.7771 - accuracy: 0.6460 - val_loss: 0.7728 - val_accuracy: 0.6561
# Epoch 8/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.7598 - accuracy: 0.6588 - val_loss: 0.6781 - val_accuracy: 0.6972
# Epoch 9/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.7366 - accuracy: 0.6698 - val_loss: 0.8186 - val_accuracy: 0.5790
# Epoch 10/300
# 930/930 [==============================] - 13s 13ms/step - loss: 0.7177 - accuracy: 0.6832 - val_loss: 0.6769 - val_accuracy: 0.7086
# Epoch 11/300
# 930/930 [==============================] - 14s 16ms/step - loss: 0.7005 - accuracy: 0.6920 - val_loss: 0.7672 - val_accuracy: 0.6511
# Epoch 12/300
# 930/930 [==============================] - 13s 13ms/step - loss: 0.6784 - accuracy: 0.7020 - val_loss: 1.0299 - val_accuracy: 0.5280
# Epoch 13/300
# 930/930 [==============================] - 12s 13ms/step - loss: 0.6696 - accuracy: 0.7085 - val_loss: 0.7417 - val_accuracy: 0.6513
# Epoch 14/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.6538 - accuracy: 0.7168 - val_loss: 0.5574 - val_accuracy: 0.7583
# Epoch 15/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.6407 - accuracy: 0.7252 - val_loss: 1.2960 - val_accuracy: 0.5290
# Epoch 16/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.6296 - accuracy: 0.7293 - val_loss: 0.6940 - val_accuracy: 0.7204
# Epoch 17/300
# 930/930 [==============================] - 12s 13ms/step - loss: 0.6171 - accuracy: 0.7355 - val_loss: 0.5107 - val_accuracy: 0.7824
# Epoch 18/300
# 930/930 [==============================] - 12s 13ms/step - loss: 0.6067 - accuracy: 0.7402 - val_loss: 0.6237 - val_accuracy: 0.7316
# Epoch 19/300
# 930/930 [==============================] - 12s 13ms/step - loss: 0.5946 - accuracy: 0.7454 - val_loss: 0.5196 - val_accuracy: 0.7778
# Epoch 20/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.5860 - accuracy: 0.7489 - val_loss: 0.5820 - val_accuracy: 0.7507
# Epoch 21/300
# 930/930 [==============================] - 12s 13ms/step - loss: 0.5717 - accuracy: 0.7580 - val_loss: 0.4355 - val_accuracy: 0.8256
# Epoch 22/300
# 930/930 [==============================] - 12s 13ms/step - loss: 0.5645 - accuracy: 0.7649 - val_loss: 0.6125 - val_accuracy: 0.7393
# Epoch 23/300
# 930/930 [==============================] - 12s 13ms/step - loss: 0.5554 - accuracy: 0.7655 - val_loss: 0.4978 - val_accuracy: 0.7993
# Epoch 24/300
# 930/930 [==============================] - 12s 13ms/step - loss: 0.5490 - accuracy: 0.7717 - val_loss: 0.5807 - val_accuracy: 0.7593
# Epoch 25/300
# 930/930 [==============================] - 12s 13ms/step - loss: 0.5414 - accuracy: 0.7739 - val_loss: 0.8556 - val_accuracy: 0.6489
# Epoch 26/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.5342 - accuracy: 0.7782 - val_loss: 0.4558 - val_accuracy: 0.8091
# Epoch 27/300
# 930/930 [==============================] - 12s 13ms/step - loss: 0.5212 - accuracy: 0.7814 - val_loss: 0.3991 - val_accuracy: 0.8375
# Epoch 28/300
# 930/930 [==============================] - 12s 13ms/step - loss: 0.5217 - accuracy: 0.7846 - val_loss: 0.9096 - val_accuracy: 0.6684
# Epoch 29/300
# 930/930 [==============================] - 12s 13ms/step - loss: 0.5155 - accuracy: 0.7882 - val_loss: 0.3841 - val_accuracy: 0.8649
# Epoch 30/300
# 930/930 [==============================] - 12s 13ms/step - loss: 0.5068 - accuracy: 0.7915 - val_loss: 0.4709 - val_accuracy: 0.8025
# Epoch 31/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.4944 - accuracy: 0.7981 - val_loss: 0.3562 - val_accuracy: 0.8617
# Epoch 32/300
# 930/930 [==============================] - 12s 13ms/step - loss: 0.4951 - accuracy: 0.7982 - val_loss: 0.3507 - val_accuracy: 0.8682
# Epoch 33/300
# 930/930 [==============================] - 12s 13ms/step - loss: 0.4848 - accuracy: 0.8020 - val_loss: 0.5105 - val_accuracy: 0.7843
# Epoch 34/300
# 930/930 [==============================] - 12s 13ms/step - loss: 0.4729 - accuracy: 0.8079 - val_loss: 0.8469 - val_accuracy: 0.6820
# Epoch 35/300
# 930/930 [==============================] - 12s 13ms/step - loss: 0.4727 - accuracy: 0.8091 - val_loss: 0.4311 - val_accuracy: 0.8233
# Epoch 36/300
# 930/930 [==============================] - 12s 13ms/step - loss: 0.4686 - accuracy: 0.8098 - val_loss: 0.4375 - val_accuracy: 0.8219
# Epoch 37/300
# 930/930 [==============================] - 13s 13ms/step - loss: 0.4603 - accuracy: 0.8153 - val_loss: 0.9219 - val_accuracy: 0.6136
# Epoch 38/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.4572 - accuracy: 0.8161 - val_loss: 0.5511 - val_accuracy: 0.7770
# Epoch 39/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.4487 - accuracy: 0.8196 - val_loss: 0.3034 - val_accuracy: 0.8891
# Epoch 40/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.4492 - accuracy: 0.8204 - val_loss: 0.3069 - val_accuracy: 0.8853
# Epoch 41/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.4423 - accuracy: 0.8240 - val_loss: 0.3088 - val_accuracy: 0.8830
# Epoch 42/300
# 930/930 [==============================] - 15s 16ms/step - loss: 0.4398 - accuracy: 0.8241 - val_loss: 0.3483 - val_accuracy: 0.8637
# Epoch 43/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.4319 - accuracy: 0.8302 - val_loss: 0.2755 - val_accuracy: 0.9007
# Epoch 44/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.4258 - accuracy: 0.8321 - val_loss: 0.2802 - val_accuracy: 0.8960
# Epoch 45/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.4241 - accuracy: 0.8318 - val_loss: 0.3232 - val_accuracy: 0.8755
# Epoch 46/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.4192 - accuracy: 0.8347 - val_loss: 0.5629 - val_accuracy: 0.7789
# Epoch 47/300
# 930/930 [==============================] - 15s 16ms/step - loss: 0.4153 - accuracy: 0.8360 - val_loss: 0.5400 - val_accuracy: 0.7716
# Epoch 48/300
# 930/930 [==============================] - 14s 16ms/step - loss: 0.4175 - accuracy: 0.8360 - val_loss: 0.6451 - val_accuracy: 0.7594
# Epoch 49/300
# 930/930 [==============================] - 15s 16ms/step - loss: 0.4041 - accuracy: 0.8407 - val_loss: 0.2734 - val_accuracy: 0.8982
# Epoch 50/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.4061 - accuracy: 0.8409 - val_loss: 0.2747 - val_accuracy: 0.8987
# Epoch 51/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.3987 - accuracy: 0.8437 - val_loss: 0.4339 - val_accuracy: 0.8179
# Epoch 52/300
# 930/930 [==============================] - 14s 16ms/step - loss: 0.3968 - accuracy: 0.8441 - val_loss: 0.3227 - val_accuracy: 0.8720
# Epoch 53/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.3952 - accuracy: 0.8459 - val_loss: 0.4131 - val_accuracy: 0.8342
# Epoch 54/300
# 930/930 [==============================] - 15s 16ms/step - loss: 0.3883 - accuracy: 0.8474 - val_loss: 0.2754 - val_accuracy: 0.8955
# Epoch 55/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.3887 - accuracy: 0.8489 - val_loss: 0.3429 - val_accuracy: 0.8720
# Epoch 56/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.3895 - accuracy: 0.8481 - val_loss: 0.4743 - val_accuracy: 0.8120
# Epoch 57/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.3778 - accuracy: 0.8529 - val_loss: 0.2586 - val_accuracy: 0.9136
# Epoch 58/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.3758 - accuracy: 0.8557 - val_loss: 0.2526 - val_accuracy: 0.9162
# Epoch 59/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.3721 - accuracy: 0.8543 - val_loss: 0.4553 - val_accuracy: 0.8127
# Epoch 60/300
# 930/930 [==============================] - 15s 16ms/step - loss: 0.3724 - accuracy: 0.8548 - val_loss: 0.2169 - val_accuracy: 0.9263
# Epoch 61/300
# 930/930 [==============================] - 15s 16ms/step - loss: 0.3738 - accuracy: 0.8564 - val_loss: 0.2639 - val_accuracy: 0.9064
# Epoch 62/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.3658 - accuracy: 0.8588 - val_loss: 0.2539 - val_accuracy: 0.9104
# Epoch 63/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.3670 - accuracy: 0.8567 - val_loss: 0.3410 - val_accuracy: 0.8651
# Epoch 64/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.3655 - accuracy: 0.8589 - val_loss: 0.2279 - val_accuracy: 0.9198
# Epoch 65/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.3606 - accuracy: 0.8616 - val_loss: 0.2528 - val_accuracy: 0.9075
# Epoch 66/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.3566 - accuracy: 0.8624 - val_loss: 0.4043 - val_accuracy: 0.8487
# Epoch 67/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.3533 - accuracy: 0.8646 - val_loss: 0.2248 - val_accuracy: 0.9226
# Epoch 68/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.3556 - accuracy: 0.8622 - val_loss: 0.2337 - val_accuracy: 0.9164
# Epoch 69/300
# 930/930 [==============================] - 15s 16ms/step - loss: 0.3500 - accuracy: 0.8647 - val_loss: 0.2424 - val_accuracy: 0.9094
# Epoch 70/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.3477 - accuracy: 0.8688 - val_loss: 0.2186 - val_accuracy: 0.9197
# Epoch 71/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.3470 - accuracy: 0.8675 - val_loss: 0.3233 - val_accuracy: 0.8785
# Epoch 72/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.3479 - accuracy: 0.8666 - val_loss: 0.2603 - val_accuracy: 0.9084
# Epoch 73/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.3366 - accuracy: 0.8716 - val_loss: 0.2673 - val_accuracy: 0.8988
# Epoch 74/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.3376 - accuracy: 0.8691 - val_loss: 0.2987 - val_accuracy: 0.8875
# Epoch 75/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.3356 - accuracy: 0.8714 - val_loss: 0.2034 - val_accuracy: 0.9310
# Epoch 76/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.3366 - accuracy: 0.8726 - val_loss: 0.2765 - val_accuracy: 0.8996
# Epoch 77/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.3338 - accuracy: 0.8745 - val_loss: 0.4371 - val_accuracy: 0.8343
# Epoch 78/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.3327 - accuracy: 0.8736 - val_loss: 0.3400 - val_accuracy: 0.8672
# Epoch 79/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.3297 - accuracy: 0.8744 - val_loss: 0.2581 - val_accuracy: 0.9044
# Epoch 80/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.3318 - accuracy: 0.8742 - val_loss: 0.2941 - val_accuracy: 0.8848
# Epoch 81/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.3297 - accuracy: 0.8745 - val_loss: 0.2763 - val_accuracy: 0.8890
# Epoch 82/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.3252 - accuracy: 0.8762 - val_loss: 0.3161 - val_accuracy: 0.8858
# Epoch 83/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.3252 - accuracy: 0.8756 - val_loss: 0.2165 - val_accuracy: 0.9235
# Epoch 84/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.3219 - accuracy: 0.8789 - val_loss: 0.2305 - val_accuracy: 0.9177
# Epoch 85/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.3189 - accuracy: 0.8796 - val_loss: 0.1973 - val_accuracy: 0.9334
# Epoch 86/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.3168 - accuracy: 0.8793 - val_loss: 0.1876 - val_accuracy: 0.9363
# Epoch 87/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.3129 - accuracy: 0.8807 - val_loss: 0.5964 - val_accuracy: 0.7743
# Epoch 88/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.3123 - accuracy: 0.8825 - val_loss: 0.2607 - val_accuracy: 0.9043
# Epoch 89/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.3123 - accuracy: 0.8822 - val_loss: 0.2487 - val_accuracy: 0.9090
# Epoch 90/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.3137 - accuracy: 0.8824 - val_loss: 0.1807 - val_accuracy: 0.9431
# Epoch 91/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.3074 - accuracy: 0.8840 - val_loss: 0.1719 - val_accuracy: 0.9428
# Epoch 92/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.3110 - accuracy: 0.8834 - val_loss: 0.2501 - val_accuracy: 0.9033
# Epoch 93/300
# 930/930 [==============================] - 13s 13ms/step - loss: 0.3035 - accuracy: 0.8866 - val_loss: 0.1837 - val_accuracy: 0.9376
# Epoch 94/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.3024 - accuracy: 0.8860 - val_loss: 0.3321 - val_accuracy: 0.8771
# Epoch 95/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.3040 - accuracy: 0.8860 - val_loss: 0.1703 - val_accuracy: 0.9475
# Epoch 96/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.3043 - accuracy: 0.8855 - val_loss: 0.1611 - val_accuracy: 0.9471
# Epoch 97/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.2982 - accuracy: 0.8876 - val_loss: 0.2628 - val_accuracy: 0.9083
# Epoch 98/300
# 930/930 [==============================] - 13s 13ms/step - loss: 0.2982 - accuracy: 0.8894 - val_loss: 0.2039 - val_accuracy: 0.9273
# Epoch 99/300
# 930/930 [==============================] - 12s 13ms/step - loss: 0.2958 - accuracy: 0.8885 - val_loss: 0.3532 - val_accuracy: 0.8565
# Epoch 100/300
# 930/930 [==============================] - 12s 13ms/step - loss: 0.2991 - accuracy: 0.8878 - val_loss: 0.1788 - val_accuracy: 0.9392
# Epoch 101/300
# 930/930 [==============================] - 12s 13ms/step - loss: 0.2971 - accuracy: 0.8886 - val_loss: 0.2503 - val_accuracy: 0.9091
# Epoch 102/300
# 930/930 [==============================] - 12s 13ms/step - loss: 0.2903 - accuracy: 0.8916 - val_loss: 0.2278 - val_accuracy: 0.9128
# Epoch 103/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.2909 - accuracy: 0.8905 - val_loss: 0.2864 - val_accuracy: 0.8945
# Epoch 104/300
# 930/930 [==============================] - 12s 13ms/step - loss: 0.2945 - accuracy: 0.8919 - val_loss: 0.2362 - val_accuracy: 0.9097
# Epoch 105/300
# 930/930 [==============================] - 12s 13ms/step - loss: 0.2885 - accuracy: 0.8925 - val_loss: 0.1961 - val_accuracy: 0.9311
# Epoch 106/300
# 930/930 [==============================] - 12s 13ms/step - loss: 0.2844 - accuracy: 0.8929 - val_loss: 0.1768 - val_accuracy: 0.9362
# Epoch 107/300
# 930/930 [==============================] - 12s 13ms/step - loss: 0.2921 - accuracy: 0.8914 - val_loss: 0.2536 - val_accuracy: 0.9037
# Epoch 108/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2848 - accuracy: 0.8935 - val_loss: 0.1540 - val_accuracy: 0.9468
# Epoch 109/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2840 - accuracy: 0.8938 - val_loss: 0.1535 - val_accuracy: 0.9464
# Epoch 110/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.2873 - accuracy: 0.8938 - val_loss: 0.1839 - val_accuracy: 0.9354
# Epoch 111/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.2844 - accuracy: 0.8934 - val_loss: 0.2089 - val_accuracy: 0.9245
# Epoch 112/300
# 930/930 [==============================] - 15s 16ms/step - loss: 0.2812 - accuracy: 0.8960 - val_loss: 0.1500 - val_accuracy: 0.9577
# Epoch 113/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.2794 - accuracy: 0.8949 - val_loss: 0.1792 - val_accuracy: 0.9392
# Epoch 114/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2815 - accuracy: 0.8958 - val_loss: 0.1463 - val_accuracy: 0.9527
# Epoch 115/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.2805 - accuracy: 0.8941 - val_loss: 0.1626 - val_accuracy: 0.9435
# Epoch 116/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.2772 - accuracy: 0.8983 - val_loss: 0.1739 - val_accuracy: 0.9407
# Epoch 117/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.2791 - accuracy: 0.8959 - val_loss: 0.4277 - val_accuracy: 0.8230
# Epoch 118/300
# 930/930 [==============================] - 15s 16ms/step - loss: 0.2779 - accuracy: 0.8970 - val_loss: 0.2763 - val_accuracy: 0.8919
# Epoch 119/300
# 930/930 [==============================] - 15s 16ms/step - loss: 0.2738 - accuracy: 0.8983 - val_loss: 0.1603 - val_accuracy: 0.9418
# Epoch 120/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.2763 - accuracy: 0.8967 - val_loss: 0.1809 - val_accuracy: 0.9354
# Epoch 121/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.2763 - accuracy: 0.8985 - val_loss: 0.3112 - val_accuracy: 0.8813
# Epoch 122/300
# 930/930 [==============================] - 14s 16ms/step - loss: 0.2724 - accuracy: 0.8988 - val_loss: 0.2071 - val_accuracy: 0.9228
# Epoch 123/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.2751 - accuracy: 0.8988 - val_loss: 0.1588 - val_accuracy: 0.9476
# Epoch 124/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.2714 - accuracy: 0.8986 - val_loss: 0.2190 - val_accuracy: 0.9182
# Epoch 125/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.2723 - accuracy: 0.9006 - val_loss: 0.1440 - val_accuracy: 0.9505
# Epoch 126/300
# 930/930 [==============================] - 15s 17ms/step - loss: 0.2741 - accuracy: 0.9011 - val_loss: 0.1614 - val_accuracy: 0.9446
# Epoch 127/300
# 930/930 [==============================] - 15s 16ms/step - loss: 0.2706 - accuracy: 0.9003 - val_loss: 0.1348 - val_accuracy: 0.9542
# Epoch 128/300
# 930/930 [==============================] - 14s 16ms/step - loss: 0.2665 - accuracy: 0.9031 - val_loss: 0.1255 - val_accuracy: 0.9601
# Epoch 129/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2605 - accuracy: 0.9019 - val_loss: 0.1403 - val_accuracy: 0.9560
# Epoch 130/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2656 - accuracy: 0.9023 - val_loss: 0.1398 - val_accuracy: 0.9567
# Epoch 131/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2617 - accuracy: 0.9040 - val_loss: 0.1535 - val_accuracy: 0.9468
# Epoch 132/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2635 - accuracy: 0.9025 - val_loss: 0.1456 - val_accuracy: 0.9519
# Epoch 133/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.2653 - accuracy: 0.9012 - val_loss: 0.1441 - val_accuracy: 0.9511
# Epoch 134/300
# 930/930 [==============================] - 15s 16ms/step - loss: 0.2628 - accuracy: 0.9044 - val_loss: 0.1314 - val_accuracy: 0.9597
# Epoch 135/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.2607 - accuracy: 0.9028 - val_loss: 0.1487 - val_accuracy: 0.9469
# Epoch 136/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.2583 - accuracy: 0.9045 - val_loss: 0.1358 - val_accuracy: 0.9563
# Epoch 137/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.2648 - accuracy: 0.9028 - val_loss: 0.1424 - val_accuracy: 0.9533
# Epoch 138/300
# 930/930 [==============================] - 15s 16ms/step - loss: 0.2607 - accuracy: 0.9037 - val_loss: 0.1345 - val_accuracy: 0.9581
# Epoch 139/300
# 930/930 [==============================] - 15s 16ms/step - loss: 0.2613 - accuracy: 0.9039 - val_loss: 0.1280 - val_accuracy: 0.9597
# Epoch 140/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.2558 - accuracy: 0.9066 - val_loss: 0.1280 - val_accuracy: 0.9577
# Epoch 141/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.2576 - accuracy: 0.9039 - val_loss: 0.1915 - val_accuracy: 0.9292
# Epoch 142/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.2556 - accuracy: 0.9065 - val_loss: 0.1399 - val_accuracy: 0.9531
# Epoch 143/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2523 - accuracy: 0.9068 - val_loss: 0.2564 - val_accuracy: 0.9022
# Epoch 144/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.2559 - accuracy: 0.9068 - val_loss: 0.1445 - val_accuracy: 0.9509
# Epoch 145/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.2534 - accuracy: 0.9072 - val_loss: 0.1468 - val_accuracy: 0.9514
# Epoch 146/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2496 - accuracy: 0.9092 - val_loss: 0.2906 - val_accuracy: 0.8979
# Epoch 147/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2540 - accuracy: 0.9062 - val_loss: 0.2074 - val_accuracy: 0.9230
# Epoch 148/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.2540 - accuracy: 0.9080 - val_loss: 0.1350 - val_accuracy: 0.9533
# Epoch 149/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2583 - accuracy: 0.9058 - val_loss: 0.1330 - val_accuracy: 0.9553
# Epoch 150/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.2537 - accuracy: 0.9067 - val_loss: 0.2507 - val_accuracy: 0.9065
# Epoch 151/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.2529 - accuracy: 0.9068 - val_loss: 0.1439 - val_accuracy: 0.9514
# Epoch 152/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2487 - accuracy: 0.9088 - val_loss: 0.2794 - val_accuracy: 0.8929
# Epoch 153/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2536 - accuracy: 0.9073 - val_loss: 0.1403 - val_accuracy: 0.9516
# Epoch 154/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2468 - accuracy: 0.9089 - val_loss: 0.1483 - val_accuracy: 0.9497
# Epoch 155/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2460 - accuracy: 0.9102 - val_loss: 0.1681 - val_accuracy: 0.9403
# Epoch 156/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.2454 - accuracy: 0.9099 - val_loss: 0.2803 - val_accuracy: 0.8926
# Epoch 157/300
# 930/930 [==============================] - 15s 16ms/step - loss: 0.2446 - accuracy: 0.9121 - val_loss: 0.1380 - val_accuracy: 0.9527
# Epoch 158/300
# 930/930 [==============================] - 15s 16ms/step - loss: 0.2447 - accuracy: 0.9106 - val_loss: 0.2580 - val_accuracy: 0.9011
# Epoch 159/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.2431 - accuracy: 0.9117 - val_loss: 0.1129 - val_accuracy: 0.9633
# Epoch 160/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.2459 - accuracy: 0.9105 - val_loss: 0.1353 - val_accuracy: 0.9575
# Epoch 161/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.2459 - accuracy: 0.9096 - val_loss: 0.1314 - val_accuracy: 0.9552
# Epoch 162/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.2475 - accuracy: 0.9104 - val_loss: 0.2897 - val_accuracy: 0.8894
# Epoch 163/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.2434 - accuracy: 0.9119 - val_loss: 0.1126 - val_accuracy: 0.9646
# Epoch 164/300
# 930/930 [==============================] - 15s 16ms/step - loss: 0.2387 - accuracy: 0.9127 - val_loss: 0.1479 - val_accuracy: 0.9490
# Epoch 165/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2422 - accuracy: 0.9116 - val_loss: 0.1247 - val_accuracy: 0.9591
# Epoch 166/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.2419 - accuracy: 0.9121 - val_loss: 0.1557 - val_accuracy: 0.9482
# Epoch 167/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2396 - accuracy: 0.9124 - val_loss: 0.4522 - val_accuracy: 0.8262
# Epoch 168/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.2399 - accuracy: 0.9125 - val_loss: 0.1727 - val_accuracy: 0.9380
# Epoch 169/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2387 - accuracy: 0.9121 - val_loss: 0.2246 - val_accuracy: 0.9180
# Epoch 170/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2396 - accuracy: 0.9119 - val_loss: 0.1244 - val_accuracy: 0.9573
# Epoch 171/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2353 - accuracy: 0.9139 - val_loss: 0.1061 - val_accuracy: 0.9693
# Epoch 172/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2429 - accuracy: 0.9117 - val_loss: 0.1149 - val_accuracy: 0.9595
# Epoch 173/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2377 - accuracy: 0.9139 - val_loss: 0.1039 - val_accuracy: 0.9674
# Epoch 174/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2344 - accuracy: 0.9147 - val_loss: 0.1495 - val_accuracy: 0.9522
# Epoch 175/300
# 930/930 [==============================] - 15s 16ms/step - loss: 0.2359 - accuracy: 0.9152 - val_loss: 0.1160 - val_accuracy: 0.9612
# Epoch 176/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2317 - accuracy: 0.9168 - val_loss: 0.1637 - val_accuracy: 0.9410
# Epoch 177/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2349 - accuracy: 0.9155 - val_loss: 0.1078 - val_accuracy: 0.9635
# Epoch 178/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2330 - accuracy: 0.9156 - val_loss: 0.1161 - val_accuracy: 0.9619
# Epoch 179/300
# 930/930 [==============================] - 15s 16ms/step - loss: 0.2351 - accuracy: 0.9145 - val_loss: 0.1062 - val_accuracy: 0.9673
# Epoch 180/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2312 - accuracy: 0.9164 - val_loss: 0.1209 - val_accuracy: 0.9593
# Epoch 181/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.2321 - accuracy: 0.9158 - val_loss: 0.1709 - val_accuracy: 0.9405
# Epoch 182/300
# 930/930 [==============================] - 15s 16ms/step - loss: 0.2294 - accuracy: 0.9158 - val_loss: 0.1356 - val_accuracy: 0.9517
# Epoch 183/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2301 - accuracy: 0.9155 - val_loss: 0.1139 - val_accuracy: 0.9632
# Epoch 184/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2311 - accuracy: 0.9161 - val_loss: 0.1369 - val_accuracy: 0.9580
# Epoch 185/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2279 - accuracy: 0.9176 - val_loss: 0.1183 - val_accuracy: 0.9609
# Epoch 186/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.2280 - accuracy: 0.9171 - val_loss: 0.1273 - val_accuracy: 0.9582
# Epoch 187/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2296 - accuracy: 0.9157 - val_loss: 0.1159 - val_accuracy: 0.9627
# Epoch 188/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2314 - accuracy: 0.9152 - val_loss: 0.1106 - val_accuracy: 0.9646
# Epoch 189/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2267 - accuracy: 0.9176 - val_loss: 0.1109 - val_accuracy: 0.9601
# Epoch 190/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2270 - accuracy: 0.9188 - val_loss: 0.1478 - val_accuracy: 0.9464
# Epoch 191/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2306 - accuracy: 0.9162 - val_loss: 0.0939 - val_accuracy: 0.9717
# Epoch 192/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2266 - accuracy: 0.9177 - val_loss: 0.3135 - val_accuracy: 0.8981
# Epoch 193/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.2281 - accuracy: 0.9180 - val_loss: 0.1068 - val_accuracy: 0.9661
# Epoch 194/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2280 - accuracy: 0.9187 - val_loss: 0.1043 - val_accuracy: 0.9670
# Epoch 195/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2272 - accuracy: 0.9183 - val_loss: 0.1196 - val_accuracy: 0.9575
# Epoch 196/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.2263 - accuracy: 0.9183 - val_loss: 0.1086 - val_accuracy: 0.9652
# Epoch 197/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2248 - accuracy: 0.9187 - val_loss: 0.2007 - val_accuracy: 0.9302
# Epoch 198/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2243 - accuracy: 0.9182 - val_loss: 0.0929 - val_accuracy: 0.9699
# Epoch 199/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2232 - accuracy: 0.9193 - val_loss: 0.0957 - val_accuracy: 0.9683
# Epoch 200/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2228 - accuracy: 0.9182 - val_loss: 0.1027 - val_accuracy: 0.9650
# Epoch 201/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2296 - accuracy: 0.9186 - val_loss: 0.1281 - val_accuracy: 0.9568
# Epoch 202/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2259 - accuracy: 0.9186 - val_loss: 0.1388 - val_accuracy: 0.9529
# Epoch 203/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2207 - accuracy: 0.9205 - val_loss: 0.1634 - val_accuracy: 0.9433
# Epoch 204/300
# 930/930 [==============================] - 13s 13ms/step - loss: 0.2226 - accuracy: 0.9208 - val_loss: 0.1113 - val_accuracy: 0.9643
# Epoch 205/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2219 - accuracy: 0.9202 - val_loss: 0.1078 - val_accuracy: 0.9665
# Epoch 206/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2217 - accuracy: 0.9196 - val_loss: 0.1080 - val_accuracy: 0.9644
# Epoch 207/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2166 - accuracy: 0.9211 - val_loss: 0.0896 - val_accuracy: 0.9718
# Epoch 208/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2171 - accuracy: 0.9202 - val_loss: 0.1021 - val_accuracy: 0.9688
# Epoch 209/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2180 - accuracy: 0.9198 - val_loss: 0.1473 - val_accuracy: 0.9452
# Epoch 210/300
# 930/930 [==============================] - 12s 13ms/step - loss: 0.2219 - accuracy: 0.9207 - val_loss: 0.1582 - val_accuracy: 0.9449
# Epoch 211/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.2274 - accuracy: 0.9203 - val_loss: 0.1151 - val_accuracy: 0.9622
# Epoch 212/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2144 - accuracy: 0.9233 - val_loss: 0.1082 - val_accuracy: 0.9652
# Epoch 213/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2205 - accuracy: 0.9193 - val_loss: 0.1089 - val_accuracy: 0.9635
# Epoch 214/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2133 - accuracy: 0.9222 - val_loss: 0.1298 - val_accuracy: 0.9555
# Epoch 215/300
# 930/930 [==============================] - 12s 13ms/step - loss: 0.2212 - accuracy: 0.9209 - val_loss: 0.1213 - val_accuracy: 0.9610
# Epoch 216/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.2172 - accuracy: 0.9214 - val_loss: 0.2272 - val_accuracy: 0.9122
# Epoch 217/300
# 930/930 [==============================] - 13s 13ms/step - loss: 0.2237 - accuracy: 0.9212 - val_loss: 0.1070 - val_accuracy: 0.9659
# Epoch 218/300
# 930/930 [==============================] - 13s 13ms/step - loss: 0.2203 - accuracy: 0.9215 - val_loss: 0.1232 - val_accuracy: 0.9584
# Epoch 219/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.2165 - accuracy: 0.9222 - val_loss: 0.1019 - val_accuracy: 0.9674
# Epoch 220/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.2183 - accuracy: 0.9223 - val_loss: 0.1235 - val_accuracy: 0.9617
# Epoch 221/300
# 930/930 [==============================] - 12s 13ms/step - loss: 0.2176 - accuracy: 0.9236 - val_loss: 0.0963 - val_accuracy: 0.9712
# Epoch 222/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.2174 - accuracy: 0.9216 - val_loss: 0.1079 - val_accuracy: 0.9637
# Epoch 223/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.2159 - accuracy: 0.9210 - val_loss: 0.0871 - val_accuracy: 0.9701
# Epoch 224/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2135 - accuracy: 0.9242 - val_loss: 0.3518 - val_accuracy: 0.8813
# Epoch 225/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2136 - accuracy: 0.9230 - val_loss: 0.1147 - val_accuracy: 0.9610
# Epoch 226/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2118 - accuracy: 0.9220 - val_loss: 0.0990 - val_accuracy: 0.9652
# Epoch 227/300
# 930/930 [==============================] - 12s 13ms/step - loss: 0.2139 - accuracy: 0.9234 - val_loss: 0.1391 - val_accuracy: 0.9514
# Epoch 228/300
# 930/930 [==============================] - 12s 13ms/step - loss: 0.2163 - accuracy: 0.9225 - val_loss: 0.0937 - val_accuracy: 0.9692
# Epoch 229/300
# 930/930 [==============================] - 12s 13ms/step - loss: 0.2171 - accuracy: 0.9230 - val_loss: 0.0961 - val_accuracy: 0.9714
# Epoch 230/300
# 930/930 [==============================] - 12s 13ms/step - loss: 0.2147 - accuracy: 0.9223 - val_loss: 0.1137 - val_accuracy: 0.9622
# Epoch 231/300
# 930/930 [==============================] - 12s 13ms/step - loss: 0.2112 - accuracy: 0.9243 - val_loss: 0.1693 - val_accuracy: 0.9387
# Epoch 232/300
# 930/930 [==============================] - 12s 13ms/step - loss: 0.2124 - accuracy: 0.9233 - val_loss: 0.1286 - val_accuracy: 0.9563
# Epoch 233/300
# 930/930 [==============================] - 13s 13ms/step - loss: 0.2093 - accuracy: 0.9240 - val_loss: 0.1192 - val_accuracy: 0.9590
# Epoch 234/300
# 930/930 [==============================] - 12s 13ms/step - loss: 0.2098 - accuracy: 0.9258 - val_loss: 0.1058 - val_accuracy: 0.9635
# Epoch 235/300
# 930/930 [==============================] - 12s 13ms/step - loss: 0.2160 - accuracy: 0.9218 - val_loss: 0.1206 - val_accuracy: 0.9617
# Epoch 236/300
# 930/930 [==============================] - 12s 13ms/step - loss: 0.2081 - accuracy: 0.9265 - val_loss: 0.1539 - val_accuracy: 0.9478
# Epoch 237/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.2130 - accuracy: 0.9244 - val_loss: 0.0922 - val_accuracy: 0.9734
# Epoch 238/300
# 930/930 [==============================] - 12s 13ms/step - loss: 0.2083 - accuracy: 0.9238 - val_loss: 0.1100 - val_accuracy: 0.9619
# Epoch 239/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.2090 - accuracy: 0.9254 - val_loss: 0.1092 - val_accuracy: 0.9654
# Epoch 240/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2066 - accuracy: 0.9257 - val_loss: 0.0863 - val_accuracy: 0.9727
# Epoch 241/300
# 930/930 [==============================] - 12s 13ms/step - loss: 0.2061 - accuracy: 0.9255 - val_loss: 0.1171 - val_accuracy: 0.9655
# Epoch 242/300
# 930/930 [==============================] - 12s 13ms/step - loss: 0.2101 - accuracy: 0.9258 - val_loss: 0.1077 - val_accuracy: 0.9614
# Epoch 243/300
# 930/930 [==============================] - 12s 13ms/step - loss: 0.2110 - accuracy: 0.9238 - val_loss: 0.1084 - val_accuracy: 0.9647
# Epoch 244/300
# 930/930 [==============================] - 12s 13ms/step - loss: 0.2081 - accuracy: 0.9251 - val_loss: 0.1103 - val_accuracy: 0.9645
# Epoch 245/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.2095 - accuracy: 0.9265 - val_loss: 0.1790 - val_accuracy: 0.9340
# Epoch 246/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2091 - accuracy: 0.9243 - val_loss: 0.0928 - val_accuracy: 0.9700
# Epoch 247/300
# 930/930 [==============================] - 12s 13ms/step - loss: 0.2104 - accuracy: 0.9257 - val_loss: 0.0918 - val_accuracy: 0.9728
# Epoch 248/300
# 930/930 [==============================] - 12s 13ms/step - loss: 0.2133 - accuracy: 0.9235 - val_loss: 0.1091 - val_accuracy: 0.9649
# Epoch 249/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2039 - accuracy: 0.9270 - val_loss: 0.0957 - val_accuracy: 0.9685
# Epoch 250/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2080 - accuracy: 0.9245 - val_loss: 0.1568 - val_accuracy: 0.9423
# Epoch 251/300
# 930/930 [==============================] - 12s 13ms/step - loss: 0.2048 - accuracy: 0.9260 - val_loss: 0.1443 - val_accuracy: 0.9504
# Epoch 252/300
# 930/930 [==============================] - 13s 13ms/step - loss: 0.2076 - accuracy: 0.9261 - val_loss: 0.0931 - val_accuracy: 0.9675
# Epoch 253/300
# 930/930 [==============================] - 12s 13ms/step - loss: 0.2019 - accuracy: 0.9275 - val_loss: 0.2223 - val_accuracy: 0.9146
# Epoch 254/300
# 930/930 [==============================] - 13s 13ms/step - loss: 0.2087 - accuracy: 0.9236 - val_loss: 0.0899 - val_accuracy: 0.9723
# Epoch 255/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2056 - accuracy: 0.9264 - val_loss: 0.1000 - val_accuracy: 0.9665
# Epoch 256/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2081 - accuracy: 0.9277 - val_loss: 0.2124 - val_accuracy: 0.9224
# Epoch 257/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2079 - accuracy: 0.9247 - val_loss: 0.0958 - val_accuracy: 0.9692
# Epoch 258/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.2060 - accuracy: 0.9246 - val_loss: 0.1419 - val_accuracy: 0.9513
# Epoch 259/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.2089 - accuracy: 0.9252 - val_loss: 0.1150 - val_accuracy: 0.9632
# Epoch 260/300
# 930/930 [==============================] - 13s 13ms/step - loss: 0.2027 - accuracy: 0.9266 - val_loss: 0.1115 - val_accuracy: 0.9638
# Epoch 261/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.1997 - accuracy: 0.9283 - val_loss: 0.0937 - val_accuracy: 0.9731
# Epoch 262/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2025 - accuracy: 0.9284 - val_loss: 0.1117 - val_accuracy: 0.9626
# Epoch 263/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.1989 - accuracy: 0.9294 - val_loss: 0.0907 - val_accuracy: 0.9727
# Epoch 264/300
# 930/930 [==============================] - 13s 13ms/step - loss: 0.2061 - accuracy: 0.9271 - val_loss: 0.0814 - val_accuracy: 0.9747
# Epoch 265/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2055 - accuracy: 0.9266 - val_loss: 0.1121 - val_accuracy: 0.9594
# Epoch 266/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2025 - accuracy: 0.9272 - val_loss: 0.1222 - val_accuracy: 0.9577
# Epoch 267/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.2033 - accuracy: 0.9275 - val_loss: 0.0928 - val_accuracy: 0.9706
# Epoch 268/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2038 - accuracy: 0.9272 - val_loss: 0.1008 - val_accuracy: 0.9638
# Epoch 269/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2040 - accuracy: 0.9274 - val_loss: 0.1168 - val_accuracy: 0.9609
# Epoch 270/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.2029 - accuracy: 0.9282 - val_loss: 0.0887 - val_accuracy: 0.9701
# Epoch 271/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.1994 - accuracy: 0.9289 - val_loss: 0.1026 - val_accuracy: 0.9666
# Epoch 272/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2016 - accuracy: 0.9284 - val_loss: 0.0909 - val_accuracy: 0.9696
# Epoch 273/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2035 - accuracy: 0.9282 - val_loss: 0.0929 - val_accuracy: 0.9709
# Epoch 274/300
# 930/930 [==============================] - 12s 13ms/step - loss: 0.2079 - accuracy: 0.9276 - val_loss: 0.1077 - val_accuracy: 0.9642
# Epoch 275/300
# 930/930 [==============================] - 12s 13ms/step - loss: 0.2034 - accuracy: 0.9273 - val_loss: 0.0765 - val_accuracy: 0.9752
# Epoch 276/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2021 - accuracy: 0.9279 - val_loss: 0.1323 - val_accuracy: 0.9551
# Epoch 277/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.1975 - accuracy: 0.9292 - val_loss: 0.0866 - val_accuracy: 0.9724
# Epoch 278/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.1951 - accuracy: 0.9307 - val_loss: 0.0951 - val_accuracy: 0.9689
# Epoch 279/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.1991 - accuracy: 0.9300 - val_loss: 0.0964 - val_accuracy: 0.9695
# Epoch 280/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.1999 - accuracy: 0.9286 - val_loss: 0.0930 - val_accuracy: 0.9714
# Epoch 281/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2006 - accuracy: 0.9292 - val_loss: 0.1269 - val_accuracy: 0.9582
# Epoch 282/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2074 - accuracy: 0.9275 - val_loss: 0.0798 - val_accuracy: 0.9748
# Epoch 283/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2001 - accuracy: 0.9296 - val_loss: 0.0860 - val_accuracy: 0.9730
# Epoch 284/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.1978 - accuracy: 0.9286 - val_loss: 0.0840 - val_accuracy: 0.9721
# Epoch 285/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.1979 - accuracy: 0.9294 - val_loss: 0.1070 - val_accuracy: 0.9668
# Epoch 286/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.1949 - accuracy: 0.9309 - val_loss: 0.0940 - val_accuracy: 0.9692
# Epoch 287/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.1994 - accuracy: 0.9301 - val_loss: 0.0878 - val_accuracy: 0.9712
# Epoch 288/300
# 930/930 [==============================] - 15s 16ms/step - loss: 0.1977 - accuracy: 0.9302 - val_loss: 0.2287 - val_accuracy: 0.9190
# Epoch 289/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.1984 - accuracy: 0.9292 - val_loss: 0.0939 - val_accuracy: 0.9715
# Epoch 290/300
# 930/930 [==============================] - 15s 16ms/step - loss: 0.1958 - accuracy: 0.9303 - val_loss: 0.0731 - val_accuracy: 0.9761
# Epoch 291/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2004 - accuracy: 0.9292 - val_loss: 0.1625 - val_accuracy: 0.9408
# Epoch 292/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.2002 - accuracy: 0.9308 - val_loss: 0.0857 - val_accuracy: 0.9708
# Epoch 293/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.1947 - accuracy: 0.9298 - val_loss: 0.0794 - val_accuracy: 0.9730
# Epoch 294/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.2032 - accuracy: 0.9295 - val_loss: 0.1405 - val_accuracy: 0.9548
# Epoch 295/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.1960 - accuracy: 0.9305 - val_loss: 0.1421 - val_accuracy: 0.9477
# Epoch 296/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.1938 - accuracy: 0.9306 - val_loss: 0.1368 - val_accuracy: 0.9519
# Epoch 297/300
# 930/930 [==============================] - 14s 15ms/step - loss: 0.1947 - accuracy: 0.9313 - val_loss: 0.1135 - val_accuracy: 0.9641
# Epoch 298/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.1915 - accuracy: 0.9319 - val_loss: 0.1711 - val_accuracy: 0.9369
# Epoch 299/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.1952 - accuracy: 0.9307 - val_loss: 0.0934 - val_accuracy: 0.9726
# Epoch 300/300
# 930/930 [==============================] - 13s 14ms/step - loss: 0.1924 - accuracy: 0.9316 - val_loss: 0.0852 - val_accuracy: 0.9733

# %%
# evaluate model
import time
start_time = time.time()
y_pred = model.predict(X_test, batch_size=64)
elapsed_time = time.time() - start_time
print(f"Elapsed time for prediction: {elapsed_time:.3f} seconds")
score = model.evaluate(X_test, y_test)
score
# Out:
# Elapsed time for prediction: 3.053 seconds
# 1138/1138 [==============================] - 4s 3ms/step - loss: 0.0864 - accuracy: 0.9734
# [0.0864231288433075, 0.9734370112419128]

# %%
epochs = [i for i in range(300)]
loss_train = history.history['loss']
acc_train = history.history['accuracy']
loss_test = history.history['val_loss']
acc_test = history.history['val_accuracy']


fig, ax = plt.subplots(1,2, figsize=(14,5))

ax[0].plot(epochs, loss_train, color='blue', label='Train Loss')
ax[0].plot(epochs, loss_test, color='orange', label='Validation Loss')
ax[0].set_title('Train and Validation Loss', fontsize=14)
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Loss')
ax[0].legend()



ax[1].plot(epochs, acc_train, color='blue', label='Train Accuracy')
ax[1].plot(epochs, acc_test, color='orange',  label='Validation Accuracy')
ax[1].set_title('Train and Validation Accuracy', fontsize=13)
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Accuracy')
ax[1].legend()
plt.show()

# %%
import time 
s1 = time.time()
y_pred = model.predict(X_test)
s2 = time.time()
s = s2 -s1 
print(s)
# Out:
# 5.1585540771484375

# %%
import numpy as np
y_test_non_category = [ np.argmax(t) for t in y_test ]
y_predict_non_category = [ np.argmax(t) for t in y_pred ]

# %%
from sklearn.metrics import confusion_matrix
confusion = confusion_matrix(y_test_non_category, y_predict_non_category)
print('Confusion Matrix\n')
print(confusion)

#importing accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
print('\nAccuracy: {:.2f}\n'.format(accuracy_score(y_test_non_category, y_predict_non_category)))

print('Micro Precision: {:.2f}'.format(precision_score(y_test_non_category, y_predict_non_category, average='micro')))
print('Micro Recall: {:.2f}'.format(recall_score(y_test_non_category, y_predict_non_category, average='micro')))
print('Micro F1-score: {:.2f}\n'.format(f1_score(y_test_non_category, y_predict_non_category, average='micro')))

print('Macro Precision: {:.2f}'.format(precision_score(y_test_non_category, y_predict_non_category, average='macro')))

print('Macro Recall: {:.2f}'.format(recall_score(y_test_non_category, y_predict_non_category, average='macro')))
print('Macro F1-score: {:.2f}\n'.format(f1_score(y_test_non_category, y_predict_non_category, average='macro')))

print('Weighted Precision: {:.2f}'.format(precision_score(y_test_non_category, y_predict_non_category, average='weighted')))
print('Weighted Recall: {:.2f}'.format(recall_score(y_test_non_category,y_predict_non_category, average='weighted')))
print('Weighted F1-score: {:.2f}'.format(f1_score(y_test_non_category, y_predict_non_category, average='weighted')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_test_non_category, y_predict_non_category, target_names=['Class 1', 'Class 2', 'Class 3']))
# Out:
# Confusion Matrix
#
# [[12220    71    94]
#  [  173 11639   212]
#  [  242   175 11578]]
#
# Accuracy: 0.97
#
# Micro Precision: 0.97
# Micro Recall: 0.97
# Micro F1-score: 0.97
#
# Macro Precision: 0.97
# Macro Recall: 0.97
# Macro F1-score: 0.97
#
# Weighted Precision: 0.97
# Weighted Recall: 0.97
# Weighted F1-score: 0.97
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#      Class 1       0.97      0.99      0.98     12385
#      Class 2       0.98      0.97      0.97     12024
#      Class 3       0.97      0.97      0.97     11995
#
#     accuracy                           0.97     36404
#    macro avg       0.97      0.97      0.97     36404
# weighted avg       0.97      0.97      0.97     36404

# %%
import seaborn as sns
from sklearn import metrics
cnf_matrix = metrics.confusion_matrix(y_test_non_category, y_predict_non_category)
cnf_matrix
# %matplotlib inline
class_names=[0,1]
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 257.44, 'Predicted label')

# %%
from itertools import cycle
from sklearn.metrics import roc_curve, auc

# %%
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(3):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_pred.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# %%
# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(3)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(3):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= 3

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
plt.figure()
plt.plot(
    fpr["micro"],
    tpr["micro"],
    label="micro-average ROC curve (area = {0:0.2f})".format(roc_auc["micro"]),
    color="deeppink",
    linestyle=":",
    linewidth=4,
)

plt.plot(
    fpr["macro"],
    tpr["macro"],
    label="macro-average ROC curve (area = {0:0.2f})".format(roc_auc["macro"]),
    color="navy",
    linestyle=":",
    linewidth=4,
)

colors = cycle(["aqua", "darkorange", "cornflowerblue"])
for i, color in zip(range(3), colors):
    plt.plot(
        fpr[i],
        tpr[i],
        color=color,
        lw=2,
        label="ROC curve of class {0} (area = {1:0.2f})".format(i, roc_auc[i]),
    )

plt.plot([0, 1], [0, 1], "k--", lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Some extension of Receiver operating characteristic to multiclass")
plt.legend(loc="lower right")
plt.show()
